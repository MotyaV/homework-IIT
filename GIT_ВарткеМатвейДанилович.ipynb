# %% [markdown]
# <font face="times new roman" size="3">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" > Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«GIT»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" > Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" >       БИК2502 </p>
#   <p  align="right"> <font face="times new roman" size="3" > Вартке Матвей Данилович</p>
#   <p  align="right"> <font face="times new roman" size="3" > Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" > Старший преподаватель кафедры ТиЗВ Егоров Дмитрий Аркадьевич  </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" > Москва, 2025 г. </p>
#
#   <hr>

# %% [markdown]
# #Цель работы
# Научиться использовать GIT и github, разместить с помощью git отчет и сайт на github

# %% [markdown]
# #Ход выполнения

# %% [markdown]
# 1. На macos git установлен по умолчанию.
#
# Вывод команды ```git --version```
#
#
# ![Снимок экрана 2025-11-04 в 02.17.08.png](data:image/png;base64,...)

# %% [markdown]
# 2. Был создан локальный репозиторий с помощью команды ```git init```
#
# ![Снимок экрана 2025-11-04 в 02.20.17.png](data:image/png;base64,...)

# %% [markdown]
# 3. Был добавлен и закомичен файл отчета с google colab
#
# ![Снимок экрана 2025-11-04 в 02.31.16.png](data:image/png;base64,...)

# %% [markdown]
# 4. Была создана ветка отчета report
#
# ![Снимок экрана 2025-11-04 в 02.35.21.png](data:image/png;base64,...)

# %% [markdown]
# 5. Закомичен отчет в ветку report
#
# ![Снимок экрана 2025-11-04 в 02.38.04.png](data:image/png;base64,...)

# %% [markdown]
# 6. Cлита ветка report с веткой main
# ```
# git checkout main
# git merge report
# ```
# ![Снимок экрана 2025-11-04 в 02.42.41.png](data:image/png;base64,...)

# %% [markdown]
# 7. Отчет залит на github с помощью команд
# ```
# git remote add origin https://github.com/MotyaV/homework-IIT.git
# git branch -M main
# git push -u origin main
# ```
#
# ![Снимок экрана 2025-11-04 в 02.52.54.png](data:image/png;base64,...)

# %% [markdown]
# 8. Далее на github был залит ранее созданный статический сайт
#
# Доступен по ссылке https://motyav.github.io/static-site/

# %% [markdown]
# #Вывод
#
# Были получены навыки использования git и github, создания локальных и удаленных репозиториев, создания и слияния веток, коммитов, а также размещения статических сайтов на github pages
